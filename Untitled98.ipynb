# %% [markdown]
# <a href="https://colab.research.google.com/github/papporica123/ai-games/blob/main/Untitled98.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
url="https://uselessfacts.jsph.pl/category/Technology.json?language=en"
def get_random_technology_fact():
  response=requests.get(url)
  if response.status_code==200:
    data=response.json()
    print(f"did you know?{fact_data['text']}")
  else:
    print("failed to fetch fact")
while True:
  user_input=input("press enter to get a random technology fact or type'q' to quit...")
  if user_input.lower()=='q':
    break
  get_random_technology_fact()
# Out:
# press enter to get a random technology fact or type'q' to quit...
# failed to fetch fact
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-449622632.py in <cell line: 0>()
#       9     print("failed to fetch fact")
#      10 while True:
# ---> 11   user_input=input("press enter to get a random technology fact or type'q' to quit...")
#      12   if user_input.lower()=='q':
#      13     break
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# ...
